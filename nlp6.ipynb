# %% [markdown]
# <a href="https://colab.research.google.com/github/ahaddd-ship-it/natural-language-proccesing/blob/main/nlp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import UnigramTagger, BigramTagger, pos_tag
from nltk.corpus import treebank
from nltk import pos_tag_sents

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# True

# %%
sample_text = "He is reading a book. Book a flight ticket for me."
#Tokenize the text
nltk.download('punkt_tab') # Download the missing 'punkt_tab' resource
tokens = word_tokenize(sample_text)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
nltk.download('averaged_perceptron_tagger_eng')
rule_based_tags = pos_tag(tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
print(rule_based_tags)
# Out:
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'VBG'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'VB'), ('a', 'DT'), ('flight', 'NN'), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]

# %%
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
nltk.help.upenn_tagset('VBP')
# Out:
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...

# %%
# Statistical Tagging using Treebank corpus-trained taggers

from nltk.corpus import treebank
from nltk.tag import UnigramTagger, BigramTagger

# Training sentences
train_sents = treebank.tagged_sents()

# Unigram Tagger
unigram_tagger = UnigramTagger(train_sents)
unigram_tags = unigram_tagger.tag(tokens)

# Bigram Tagger
bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
bigram_tags = bigram_tagger.tag(tokens)

print("Unigram Tags:")
print(unigram_tags)

print("\nBigram Tags:")
print(bigram_tags)
# Out:
# Unigram Tags:
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'NN'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'NNP'), ('a', 'DT'), ('flight', None), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]
#
# Bigram Tags:
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'NN'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'NNP'), ('a', 'DT'), ('flight', None), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]

# %%
nltk.help.upenn_tagset('IN')
# Out:
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...

# %%
print("Original Sentence:", sample_text)

print("\nRule-Based POS Tagging (Statistical):")
print(rule_based_tags)

print("\nUnigram POS Tagging:")
print(unigram_tags)

print("\nBigram POS Tagging:")
print(bigram_tags)
# Out:
# Original Sentence: He is reading a book. Book a flight ticket for me.
#
# Rule-Based POS Tagging (Statistical):
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'VBG'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'VB'), ('a', 'DT'), ('flight', 'NN'), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]
#
# Unigram POS Tagging:
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'NN'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'NNP'), ('a', 'DT'), ('flight', None), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]
#
# Bigram POS Tagging:
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'NN'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'NNP'), ('a', 'DT'), ('flight', None), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]

# %%
bigram_tags
# Out:
# [('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('reading', 'NN'),
#  ('a', 'DT'),
#  ('book', 'NN'),
#  ('.', '.'),
#  ('Book', 'NNP'),
#  ('a', 'DT'),
#  ('flight', None),
#  ('ticket', 'NN'),
#  ('for', 'IN'),
#  ('me', 'PRP'),
#  ('.', '.')]
